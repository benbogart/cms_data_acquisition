# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup-Database-Connection" data-toc-modified-id="Setup-Database-Connection-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup Database Connection</a></span><ul class="toc-item"><li><span><a href="#Get-last-record" data-toc-modified-id="Get-last-record-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Get last record</a></span></li></ul></li><li><span><a href="#Scrape-URLs" data-toc-modified-id="Scrape-URLs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Scrape URLs</a></span><ul class="toc-item"><li><span><a href="#Collect-all-URLs-for-each-report" data-toc-modified-id="Collect-all-URLs-for-each-report-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Collect all URLs for each report</a></span></li><li><span><a href="#Sanity-Check" data-toc-modified-id="Sanity-Check-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Sanity Check</a></span></li></ul></li><li><span><a href="#Download,-Extract,-Import" data-toc-modified-id="Download,-Extract,-Import-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Download, Extract, Import</a></span></li><li><span><a href="#Compare-which-info-in-cpsc_contract_info-changes" data-toc-modified-id="Compare-which-info-in-cpsc_contract_info-changes-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compare which info in cpsc_contract_info changes</a></span></li><li><span><a href="#Schema" data-toc-modified-id="Schema-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Schema</a></span></li><li><span><a href="#TODO" data-toc-modified-id="TODO-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TODO</a></span></li></ul></div>

# %% [markdown]
# This is prototype for automatic scraping of one report type using methods from utils.py and db_operations.py

# %%
from bs4 import BeautifulSoup
import requests
import requests_cache

import pandas as pd
import numpy as np
import os
import shutil

from urllib.parse import urljoin, urlparse
from tqdm import tqdm

import time
import zipfile

import matplotlib.pyplot as plt
import seaborn as sns

from glob import glob
import re
import json

from datetime import datetime

# %%
# start requests cache so we can rurun the notebook without querying cms.gov
requests_cache.install_cache('cms_cache')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import utils
import table_schema
from db_operations import CRM_DB

# %%
# constants
DOWNLOADS_TABLE = 'meta_downloads'
DOWNLOAD_FILES_PATH = 'files'
START_URL = 'https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County'

# %%
# display clickable url
print(START_URL)
# Out:
# https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County

# %% [markdown]
# # Setup Database Connection
# Pandas can write directly to an SQL database if given a SQLAlchemy engine or sqlite3 connection object.  Because we will later be using MySQL I will directly implement SQLAlchemy engine, but on a local sqlite db.

# %%
from sqlalchemy import create_engine
create_engine('sqlite:///test_db', echo=False)
# Out:
# Engine(sqlite:///test_db)

# %%
db = CRM_DB('sqlite:///test_db')

# %%
# db.metadata.reflect()
db.metadata.tables.keys()
# Out:
# dict_keys(['meta_downloads', 'cpsc_contract_info', 'cpsc_enrollment_info', 'monthly_report_by_contract'])

# %%
db.metadata.tables['meta_downloads']
# Out:
# Table('meta_downloads', MetaData(bind=Engine(sqlite:///test_db)), Column('ID', Integer(), table=<meta_downloads>, primary_key=True, nullable=False), Column('Table', String(), table=<meta_downloads>), Column('Prefix', String(), table=<meta_downloads>), Column('Filename', String(), table=<meta_downloads>), Column('URL', String(), table=<meta_downloads>), Column('Period', Date(), table=<meta_downloads>), schema=None)

# %% [markdown]
# ## Get last record
# TODO: Find a starting point, either by:
#    1. querying a list of zip files that have been imported
#    1. getting the last date of an imported record from the set.
#
# To test this we need a fully constructed database so we will come back to it.

# %%
last_period = db.get_last_period('meta_downloads')
last_period
# Out:
# 0

# %% [markdown]
# # Scrape URLs

# %% [markdown]
# ## Collect all URLs for each report
#
# Passing in last_period will acquire all download links, but only return downloads from after `last_period`

# %%
# get dataframes of all download links from oldest to newest
df = utils.get_all_downloads(START_URL, last_period=last_period, verbose=False)[::-1]
# Out:
# starting to extract urls
# Extracting links from 100 rows
# number of urls extrated 100
# starting to extract urls
# Extracting links from 81 rows
# number of urls extrated 81
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/enrollment-contract-2021-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2021-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-03-0
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/research-statistics-data-and-systemsstatistics-trends-and-reportsmcradvpartdenroldatamonthly/monthly-enrollment-cpsc-2020-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/httpswwwcmsgovresearch-statistics-data-and-systemsstatistics-trends-and/monthly-enrollment-cpsc-2019-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/monthly-enrollment-cpsc-2019-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2019-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-09-
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2018-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2017-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2016-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2015-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-12-Fixed
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2014-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-8
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2013-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2012-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1256746
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1255802
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1255430
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1254858
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1254097
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1252944
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1252038
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1250911
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1249621
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1248592
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1247516
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1246812
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1245790
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1244159
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1243101
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1242302
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1241359-CPSC-2010-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1240300
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1239273
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1238269
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1237377
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1236146
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1235529
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1234513-CPSC-2010-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1233914
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1233073
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1232390
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1231975
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1230399
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1229578
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1228481
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1227811
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2009-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1224349
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1222642
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1221839
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1221060
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1220465
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1223265
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1218427
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1217408
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1244873
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1214867
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2008-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1227575-CPSC-2008-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1211854
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/CMS1211538-CPSC-2008-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2008-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2008-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2008-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2008-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-07
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-06
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-05
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-04
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-03
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-02
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2007-01
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-12
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-11
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-10
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-09
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-08
# --> recursion: 1
# --> extracting downloads
# Accessing https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/MCRAdvPartDEnrolData/Monthly-Enrollment-by-Contract-Plan-State-County-Items/Monthly-Enrollment-by-CPSC-2006-07
# --> recursion: 1
# --> extracting downloads

# %%
df
# Out:
#    report_period                                      report_title  \
# 0        2006-07      Monthly Enrollment by CPSC - July 2006 (ZIP)
# 0        2006-08    Monthly Enrollment by CPSC - August 2006 (ZIP)
# 0        2006-09      Monthly Enrollment by CPSC - Sept 2006 (ZIP)
# 0        2006-10   Monthly Enrollment by CPSC - October 2006 (ZIP)
# 0        2006-11  Monthly Enrollment by CPSC - November 2006 (ZIP)
# ..           ...                                               ...
# 0        2021-03     Monthly Enrollment by CPSC – March 2021 (ZIP)
# 0        2021-04     Monthly Enrollment by CPSC – April 2021 (ZIP)
# 0        2021-05       Monthly Enrollment by CPSC – May 2021 (ZIP)
# 0        2021-06      Monthly Enrollment by CPSC – June 2021 (ZIP)
# 0        2021-06  Monthly Enrollment by Contract – June 2021 (ZIP)
#
#                                          download_url  \
# 0   /Research-Statistics-Data-and-Systems/Statisti...
# 0   /Research-Statistics-Data-and-Systems/Statisti...
# 0   /Research-Statistics-Data-and-Systems/Statisti...
# 0   /Research-Statistics-Data-and-Systems/Statisti...
# 0   /Research-Statistics-Data-and-Systems/Statisti...
# ..                                                ...
# 0   /files/zip/monthly-enrollment-cpsc-march-2021.zip
# 0   /files/zip/monthly-enrollment-cpsc-april-2021.zip
# 0     /files/zip/monthly-enrollment-cpsc-may-2021.zip
# 0    /files/zip/monthly-enrollment-cpsc-june-2021.zip
# 0   /files/zip/monthly-enrollment-contract-june-20...
#
#                                     download_page_url  \
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# ..                                                ...
# 0   https://www.cms.gov/research-statistics-data-a...
# 0   https://www.cms.gov/research-statistics-data-a...
# 0   https://www.cms.gov/research-statistics-data-a...
# 0   https://www.cms.gov/research-statistics-data-a...
# 0   https://www.cms.gov/research-statistics-data-a...
#
#                                           description  \
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# ..                                                ...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
# 0   Provides monthly enrollment at the contract/pl...
#
#                                           page_title  \
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# ..                                               ...
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
# 0   Monthly Enrollment by Contract/Plan/State/County
#
#                                              page_url
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# ..                                                ...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
# 0   https://www.cms.gov/Research-Statistics-Data-a...
#
# [181 rows x 7 columns]

# %% [markdown]
# ## Sanity Check

# %%
# Unique page urls == 1
df['page_url'].nunique()
# Out:
# 1

# %%
# Unique page titles = 1
df['page_title'].nunique()
# Out:
# 1

# %%
# num download urls (total files to download)
df['download_url'].nunique()
# Out:
# 181

# %%
soup = utils.get_page_soup(START_URL)
utils.extract_num_entries(soup)
# Out:
# 181

# %%
df.shape
# Out:
# (181, 7)

# %% [markdown]
# # Download, Extract, Import

# %%
os.remove('test_db')
db = CRM_DB('sqlite:///test_db')

# %%
start_time = datetime.now()

# loop through files in each zip

# TODO: temporarily limit to 2
for idx, row in df.iterrows():
    
    print(row)
    
    period = pd.to_datetime(row['report_period'])
    
    # download file
    url = urljoin(START_URL, row['download_url'])
    prefix, filename = utils.download_file(url, DOWNLOAD_FILES_PATH)
    
    zip_file_meta = {'Prefix': prefix,
                 'Filename': filename,
                 'URL': url,
                 'Period': pd.to_datetime(row['report_period']),
                 }
    
    # extract zip file to temp_dir
    zipfile_path = os.path.join(DOWNLOAD_FILES_PATH, prefix, filename)
    tmp_dir='tmp_dir' 
    utils.extract_zip(zipfile_path, tmp_dir=tmp_dir)
    
    # get list of all unzipped files
    files = glob(os.path.join(tmp_dir, '**/*.*'), recursive=True)
    #print(files)
    
    # parse tables and filenames
    parsed_files = utils.parse_files_by_table(files)
    display(parsed_files)
    
    updated_tables = []
    # loop through files and store in db
    for table, file in parsed_files.items():
        
        
        # create record in meta_downloads for this insert
        zip_file_meta['Table'] = table
        meta_downloads_id = db.insert_dict(DOWNLOADS_TABLE, zip_file_meta)
        print('Zip file row created with id', meta_downloads_id)
        
        # load the file into a df
        _, ext = os.path.splitext(file)
        if ext == '.csv':
            file_df = pd.read_csv(file, encoding='latin1')
        else:
            raise Exception(f'File type "{ext}" not handled')
        
        print('insert shape:', file_df.shape)
        print('Time Elapsed:', datetime.now()-start_time)
        
        file_df = utils.prepare_table_for_insert(file_df, period)
        print('DataFrame prepared for insert')
        print('Time Elapsed:', datetime.now()-start_time)
        
        
        # TODO - check if the table rows should be inserted or updated and act.
        
        db.insert_df(table, file_df)
        print('inserted performed on ', table)
        print('Time Elapsed:', datetime.now()-start_time)
        
        # update meta_downloads to indicate success
        db.mark_success(meta_downloads_id)

    print('Time Elapsed:', datetime.now()-start_time)
    # remove extracted files
    shutil.rmtree(tmp_dir)

    # shutil.rmtree is SLOW
#     os.system(f'rm -fr "{tmp_dir}"')

    print('folder removed')
    print('Time Elapsed:', datetime.now()-start_time)

    
print('Time Elapsed:', datetime.now()-start_time)
# Out:
# report_period                                                  2006-07
# report_title              Monthly Enrollment by CPSC - July 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_07.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_07.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_07.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_07.csv'}
# Zip file row created with id 1
# insert shape: (4924, 12)
# Time Elapsed: 0:00:02.663007
# DataFrame prepared for insert
# Time Elapsed: 0:00:02.899689
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:00:03.236572
# Zip file row created with id 2
# insert shape: (1227922, 7)
# Time Elapsed: 0:00:04.797737
# DataFrame prepared for insert
# Time Elapsed: 0:00:06.616601
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 0:00:33.494519
# Time Elapsed: 0:00:33.501802
# folder removed
# Time Elapsed: 0:00:33.502445
# report_period                                                  2006-08
# report_title            Monthly Enrollment by CPSC - August 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_08.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_08.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_08.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_08.csv'}
# Zip file row created with id 3
# insert shape: (4923, 12)
# Time Elapsed: 0:00:34.782747
# DataFrame prepared for insert
# Time Elapsed: 0:00:34.809162
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:00:35.316051
# Zip file row created with id 4
# insert shape: (1235096, 7)
# Time Elapsed: 0:00:36.714036
# DataFrame prepared for insert
# Time Elapsed: 0:00:39.108306
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 0:01:31.424072
# Time Elapsed: 0:01:31.466928
# folder removed
# Time Elapsed: 0:01:31.467620
# report_period                                                  2006-09
# report_title              Monthly Enrollment by CPSC - Sept 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_09.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_09.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_09.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_09.csv'}
# Zip file row created with id 5
# insert shape: (4923, 12)
# Time Elapsed: 0:01:33.201185
# DataFrame prepared for insert
# Time Elapsed: 0:01:33.232473
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:01:34.837912
# Zip file row created with id 6
# insert shape: (1242099, 7)
# Time Elapsed: 0:01:39.347467
# DataFrame prepared for insert
# Time Elapsed: 0:01:41.053231
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 0:09:16.736559
# Time Elapsed: 0:09:16.832562
# folder removed
# Time Elapsed: 0:09:16.907104
# report_period                                                  2006-10
# report_title           Monthly Enrollment by CPSC - October 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_10.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_10.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_10.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_10.csv'}
# Zip file row created with id 7
# insert shape: (4923, 12)
# Time Elapsed: 0:09:22.904128
# DataFrame prepared for insert
# Time Elapsed: 0:09:22.933547
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:09:26.070243
# Zip file row created with id 8
# insert shape: (1246628, 7)
# Time Elapsed: 0:09:30.270775
# DataFrame prepared for insert
# Time Elapsed: 0:09:31.944110
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 0:22:27.057459
# Time Elapsed: 0:22:27.321330
# folder removed
# Time Elapsed: 0:22:27.340133
# report_period                                                  2006-11
# report_title          Monthly Enrollment by CPSC - November 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_11.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_11.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_11.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_11.csv'}
# Zip file row created with id 9
# insert shape: (4923, 12)
# Time Elapsed: 0:22:38.838674
# DataFrame prepared for insert
# Time Elapsed: 0:22:38.875182
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:22:44.925114
# Zip file row created with id 10
# insert shape: (1251051, 7)
# Time Elapsed: 0:22:46.610595
# DataFrame prepared for insert
# Time Elapsed: 0:22:48.313955
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 0:39:33.707354
# Time Elapsed: 0:39:33.909402
# folder removed
# Time Elapsed: 0:39:34.065620
# report_period                                                  2006-12
# report_title          Monthly Enrollment by CPSC - December 2006 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2006_12.csv', 'tmp_dir/CPSC_Enrollment_Info_2006_12.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2006.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2006_12.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2006_12.csv'}
# Zip file row created with id 11
# insert shape: (4922, 12)
# Time Elapsed: 0:39:42.624920
# DataFrame prepared for insert
# Time Elapsed: 0:39:42.688334
# inserted performed on  cpsc_contract_info
# Time Elapsed: 0:39:52.453508
# Zip file row created with id 12
# insert shape: (1254932, 7)
# Time Elapsed: 0:39:53.784138
# DataFrame prepared for insert
# Time Elapsed: 0:39:55.429549
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 1:01:46.939729
# Time Elapsed: 1:01:46.993977
# folder removed
# Time Elapsed: 1:01:47.124335
# report_period                                                  2007-01
# report_title           Monthly Enrollment by CPSC - January 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_01.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_01.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_01.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_01.csv'}
# Zip file row created with id 13
# insert shape: (5853, 12)
# Time Elapsed: 1:01:52.901399
# DataFrame prepared for insert
# Time Elapsed: 1:01:54.221319
# inserted performed on  cpsc_contract_info
# Time Elapsed: 1:02:09.661136
# Zip file row created with id 14
# insert shape: (1440703, 7)
# Time Elapsed: 1:02:10.875774
# DataFrame prepared for insert
# Time Elapsed: 1:02:12.411588
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 1:15:34.465111
# Time Elapsed: 1:15:34.538249
# folder removed
# Time Elapsed: 1:15:34.808490
# report_period                                                  2007-02
# report_title          Monthly Enrollment by CPSC - February 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_02.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_02.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_02.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_02.csv'}
# Zip file row created with id 15
# insert shape: (5885, 12)
# Time Elapsed: 1:15:44.981193
# DataFrame prepared for insert
# Time Elapsed: 1:15:46.187805
# inserted performed on  cpsc_contract_info
# Time Elapsed: 1:15:52.726183
# Zip file row created with id 16
# insert shape: (1459039, 7)
# Time Elapsed: 1:15:54.407073
# DataFrame prepared for insert
# Time Elapsed: 1:15:55.935891
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 1:35:03.670976
# Time Elapsed: 1:35:03.752990
# folder removed
# Time Elapsed: 1:35:03.859844
# report_period                                                  2007-03
# report_title             Monthly Enrollment by CPSC - March 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_03.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_03.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_03.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_03.csv'}
# Zip file row created with id 17
# insert shape: (5879, 12)
# Time Elapsed: 1:35:14.931479
# DataFrame prepared for insert
# Time Elapsed: 1:35:16.629895
# inserted performed on  cpsc_contract_info
# Time Elapsed: 1:35:19.069011
# Zip file row created with id 18
# insert shape: (1456156, 7)
# Time Elapsed: 1:35:20.826771
# DataFrame prepared for insert
# Time Elapsed: 1:35:22.915444
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 1:57:48.344930
# Time Elapsed: 1:57:48.436421
# folder removed
# Time Elapsed: 1:57:48.587345
# report_period                                                  2007-04
# report_title             Monthly Enrollment by CPSC - April 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_04.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_04.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_04.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_04.csv'}
# Zip file row created with id 19
# insert shape: (5879, 12)
# Time Elapsed: 1:57:58.365459
# DataFrame prepared for insert
# Time Elapsed: 1:57:59.638949
# inserted performed on  cpsc_contract_info
# Time Elapsed: 1:58:07.107042
# Zip file row created with id 20
# insert shape: (1458589, 7)
# Time Elapsed: 1:58:08.301894
# DataFrame prepared for insert
# Time Elapsed: 1:58:09.695765
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 2:27:07.317563
# Time Elapsed: 2:27:07.679837
# folder removed
# Time Elapsed: 2:27:07.699831
# report_period                                                  2007-05
# report_title               Monthly Enrollment by CPSC - May 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_05.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_05.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_05.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_05.csv'}
# Zip file row created with id 21
# insert shape: (5879, 12)
# Time Elapsed: 2:27:15.833038
# DataFrame prepared for insert
# Time Elapsed: 2:27:16.590691
# inserted performed on  cpsc_contract_info
# Time Elapsed: 2:27:26.970032
# Zip file row created with id 22
# insert shape: (1460942, 7)
# Time Elapsed: 2:27:28.381939
# DataFrame prepared for insert
# Time Elapsed: 2:27:29.934514
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 3:03:40.236618
# Time Elapsed: 3:03:40.443835
# folder removed
# Time Elapsed: 3:03:40.673185
# report_period                                                  2007-06
# report_title              Monthly Enrollment by CPSC - June 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_06.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_06.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_06.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_06.csv'}
# Zip file row created with id 23
# insert shape: (5886, 12)
# Time Elapsed: 3:03:49.629433
# DataFrame prepared for insert
# Time Elapsed: 3:03:50.563264
# inserted performed on  cpsc_contract_info
# Time Elapsed: 3:03:54.292109
# Zip file row created with id 24
# insert shape: (1466810, 7)
# Time Elapsed: 3:03:55.510328
# DataFrame prepared for insert
# Time Elapsed: 3:03:57.006104
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 3:44:50.048340
# Time Elapsed: 3:44:50.234722
# folder removed
# Time Elapsed: 3:44:50.329989
# report_period                                                  2007-07
# report_title              Monthly Enrollment by CPSC - July 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_07.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_07.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_07.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_07.csv'}
# Zip file row created with id 25
# insert shape: (5882, 12)
# Time Elapsed: 3:45:02.081057
# DataFrame prepared for insert
# Time Elapsed: 3:45:03.219566
# inserted performed on  cpsc_contract_info
# Time Elapsed: 3:45:11.381945
# Zip file row created with id 26
# insert shape: (1469110, 7)
# Time Elapsed: 3:45:12.609464
# DataFrame prepared for insert
# Time Elapsed: 3:45:14.164158
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 4:30:44.703441
# Time Elapsed: 4:30:44.776010
# folder removed
# Time Elapsed: 4:30:44.792666
# report_period                                                  2007-08
# report_title            Monthly Enrollment by CPSC - August 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_08.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_08.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_08.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_08.csv'}
# Zip file row created with id 27
# insert shape: (5882, 12)
# Time Elapsed: 4:30:52.724547
# DataFrame prepared for insert
# Time Elapsed: 4:30:53.193211
# inserted performed on  cpsc_contract_info
# Time Elapsed: 4:31:06.218191
# Zip file row created with id 28
# insert shape: (1474190, 7)
# Time Elapsed: 4:31:07.961478
# DataFrame prepared for insert
# Time Elapsed: 4:31:10.769836
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 5:22:20.747057
# Time Elapsed: 5:22:20.921306
# folder removed
# Time Elapsed: 5:22:20.968867
# report_period                                                  2007-09
# report_title         Monthly Enrollment by CPSC - September 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_09.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_09.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_09.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_09.csv'}
# Zip file row created with id 29
# insert shape: (5861, 12)
# Time Elapsed: 5:22:29.885877
# DataFrame prepared for insert
# Time Elapsed: 5:22:30.828804
# inserted performed on  cpsc_contract_info
# Time Elapsed: 5:22:42.858651
# Zip file row created with id 30
# insert shape: (1481185, 7)
# Time Elapsed: 5:22:44.049525
# DataFrame prepared for insert
# Time Elapsed: 5:22:46.401706
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 6:21:37.570997
# Time Elapsed: 6:21:37.677314
# folder removed
# Time Elapsed: 6:21:37.948690
# report_period                                                  2007-10
# report_title           Monthly Enrollment by CPSC - October 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_10.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_10.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_10.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_10.csv'}
# Zip file row created with id 31
# insert shape: (5859, 12)
# Time Elapsed: 6:21:48.349650
# DataFrame prepared for insert
# Time Elapsed: 6:21:49.831935
# inserted performed on  cpsc_contract_info
# Time Elapsed: 6:22:01.875026
# Zip file row created with id 32
# insert shape: (1483319, 7)
# Time Elapsed: 6:22:05.031720
# DataFrame prepared for insert
# Time Elapsed: 6:22:06.584119
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 7:26:31.784052
# Time Elapsed: 7:26:32.298261
# folder removed
# Time Elapsed: 7:26:32.577138
# report_period                                                  2007-11
# report_title          Monthly Enrollment by CPSC - November 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_11.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_11.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_11.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_11.csv'}
# Zip file row created with id 33
# insert shape: (5862, 12)
# Time Elapsed: 7:26:40.756325
# DataFrame prepared for insert
# Time Elapsed: 7:26:41.673136
# inserted performed on  cpsc_contract_info
# Time Elapsed: 7:26:52.993256
# Zip file row created with id 34
# insert shape: (1486908, 7)
# Time Elapsed: 7:26:54.231917
# DataFrame prepared for insert
# Time Elapsed: 7:26:56.489313
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 8:37:07.614158
# Time Elapsed: 8:37:07.658815
# folder removed
# Time Elapsed: 8:37:08.614724
# report_period                                                  2007-12
# report_title          Monthly Enrollment by CPSC - December 2007 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2007_12.csv', 'tmp_dir/CPSC_Enrollment_Info_2007_12.csv', 'tmp_dir/Read_Me_CPSC_Enrollment_2007.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2007_12.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2007_12.csv'}
# Zip file row created with id 35
# insert shape: (5859, 12)
# Time Elapsed: 8:37:18.527115
# DataFrame prepared for insert
# Time Elapsed: 8:37:19.333831
# inserted performed on  cpsc_contract_info
# Time Elapsed: 8:37:33.632935
# Zip file row created with id 36
# insert shape: (1491356, 7)
# Time Elapsed: 8:37:37.404743
# DataFrame prepared for insert
# Time Elapsed: 8:37:39.627677
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 9:50:31.612599
# Time Elapsed: 9:50:31.657071
# folder removed
# Time Elapsed: 9:50:31.703945
# report_period                                                  2008-01
# report_title           Monthly Enrollment by CPSC - January 2008 (ZIP)
# download_url         /Research-Statistics-Data-and-Systems/Statisti...
# download_page_url    https://www.cms.gov/Research-Statistics-Data-a...
# description          Provides monthly enrollment at the contract/pl...
# page_title            Monthly Enrollment by Contract/Plan/State/County
# page_url             https://www.cms.gov/Research-Statistics-Data-a...
# Name: 0, dtype: object
# ['tmp_dir/CPSC_Contract_Info_2008_01.csv', 'tmp_dir/CPSC_Enrollment_Info_2008_01.csv', 'tmp_dir/readme_CPSC_enrollment_2008.txt']
# {'cpsc_contract_info': 'tmp_dir/CPSC_Contract_Info_2008_01.csv',
#  'cpsc_enrollment_info': 'tmp_dir/CPSC_Enrollment_Info_2008_01.csv',
#  'readme_cpsc_enrollment': 'tmp_dir/readme_CPSC_enrollment_2008.txt'}
# Zip file row created with id 37
# insert shape: (6839, 12)
# Time Elapsed: 9:50:41.529769
# DataFrame prepared for insert
# Time Elapsed: 9:50:42.731893
# inserted performed on  cpsc_contract_info
# Time Elapsed: 9:50:54.468286
# Zip file row created with id 38
# insert shape: (1786610, 7)
# Time Elapsed: 9:50:56.031169
# DataFrame prepared for insert
# Time Elapsed: 9:50:57.740511
# inserted performed on  cpsc_enrollment_info
# Time Elapsed: 11:00:25.634716
# Zip file row created with id 39
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-199-27ea86a4d4d9> in <module>
#      48             file_df = pd.read_csv(file, encoding='latin1')
#      49         else:
# ---> 50             raise Exception(f'File type "{ext}" not handled')
#      51
#      52         print('insert shape:', file_df.shape)
#
# Exception: File type ".txt" not handled

# %%
downloads = db.query('SELECT * FROM meta_downloads ORDER BY id DESC LIMIT 100')
downloads
# Out:
#    ID                       Table                      Prefix  \
# 0   7        cpsc_enrollment_info             cpsc_enrollment
# 1   6          cpsc_contract_info             cpsc_enrollment
# 2   5  monthly_report_by_contract  monthly_report_by_contract
# 3   4        cpsc_enrollment_info             cpsc_enrollment
# 4   3          cpsc_contract_info             cpsc_enrollment
# 5   2        cpsc_enrollment_info             cpsc_enrollment
# 6   1          cpsc_contract_info             cpsc_enrollment
#
#                                  Filename  \
# 0             CPSC_Enrollment_2021_06.zip
# 1             CPSC_Enrollment_2021_06.zip
# 2  Monthly_Report_By_Contract_2021_06.zip
# 3             CPSC_Enrollment_2006_09.zip
# 4             CPSC_Enrollment_2006_09.zip
# 5             CPSC_Enrollment_2006_08.zip
# 6             CPSC_Enrollment_2006_08.zip
#
#                                                  URL      Period  Succsess
# 0  https://www.cms.gov/files/zip/monthly-enrollme...  2021-06-01         1
# 1  https://www.cms.gov/files/zip/monthly-enrollme...  2021-06-01         1
# 2  https://www.cms.gov/files/zip/monthly-enrollme...  2021-06-01         1
# 3  https://www.cms.gov/Research-Statistics-Data-a...  2006-09-01         1
# 4  https://www.cms.gov/Research-Statistics-Data-a...  2006-09-01         1
# 5  https://www.cms.gov/Research-Statistics-Data-a...  2006-08-01         1
# 6  https://www.cms.gov/Research-Statistics-Data-a...  2006-08-01         1

# %%
db.query('SELECT * FROM cpsc_enrollment_info ORDER BY id DESC LIMIT 100')
# Out:
#          ID ContractNumber  PlanID  SSAStateCountyCode  FIPSStateCountyCode  \
# 0   1235096          S9264     802               53220                56045
# 1   1235095          S9264     802               53210                56043
# 2   1235094          S9264     802               53200                56041
# 3   1235093          S9264     802               53190                56039
# 4   1235092          S9264     802               53180                56037
# ..      ...            ...     ...                 ...                  ...
# 95  1235001          S9264     802               51540                54109
# 96  1235000          S9264     802               51530                54107
# 97  1234999          S9264     802               51520                54105
# 98  1234998          S9264     802               51510                54103
# 99  1234997          S9264     802               51500                54101
#
#    State      County  Enrollment                      Period
# 0     WY      Weston           5  2006-08-01 00:00:00.000000
# 1     WY    Washakie           5  2006-08-01 00:00:00.000000
# 2     WY       Uinta           5  2006-08-01 00:00:00.000000
# 3     WY       Teton           5  2006-08-01 00:00:00.000000
# 4     WY  Sweetwater           5  2006-08-01 00:00:00.000000
# ..   ...         ...         ...                         ...
# 95    WV     Wyoming           5  2006-08-01 00:00:00.000000
# 96    WV        Wood           5  2006-08-01 00:00:00.000000
# 97    WV        Wirt           5  2006-08-01 00:00:00.000000
# 98    WV      Wetzel           5  2006-08-01 00:00:00.000000
# 99    WV     Webster           5  2006-08-01 00:00:00.000000
#
# [100 rows x 9 columns]

# %%
db.query('SELECT * FROM cpsc_contract_info ORDER BY id DESC LIMIT 100')
# Out:
#       ID ContractID  PlanID                 OrganizationType  \
# 0   4923      S9264     802  Medicare Prescription Drug Plan
# 1   4922      S9264     801  Medicare Prescription Drug Plan
# 2   4921      S9086       1  Medicare Prescription Drug Plan
# 3   4920      S8067     802  Medicare Prescription Drug Plan
# 4   4919      S8067     801  Medicare Prescription Drug Plan
# ..   ...        ...     ...                              ...
# 95  4828      S5967      60  Medicare Prescription Drug Plan
# 96  4827      S5967      59  Medicare Prescription Drug Plan
# 97  4826      S5967      58  Medicare Prescription Drug Plan
# 98  4825      S5967      57  Medicare Prescription Drug Plan
# 99  4824      S5967      56  Medicare Prescription Drug Plan
#
#                            PlanType  OffersPartD  SNPPlan  EGHP  \
# 0   Medicare Prescription Drug Plan            1        0     1
# 1   Medicare Prescription Drug Plan            1        0     1
# 2   Medicare Prescription Drug Plan            1        0     0
# 3   Medicare Prescription Drug Plan            1        0     1
# 4   Medicare Prescription Drug Plan            1        0     1
# ..                              ...          ...      ...   ...
# 95  Medicare Prescription Drug Plan            1        0     0
# 96  Medicare Prescription Drug Plan            1        0     0
# 97  Medicare Prescription Drug Plan            1        0     0
# 98  Medicare Prescription Drug Plan            1        0     0
# 99  Medicare Prescription Drug Plan            1        0     0
#
#                          OrganizationName OrganizationMarketingName  \
# 0         STERLING LIFE INSURANCE COMPANY       Sterling Retiree Rx
# 1         STERLING LIFE INSURANCE COMPANY       Sterling Retiree Rx
# 2                  AMERICA'S HEALTHCHOICE   America's Health Choice
# 3                AVALON INSURANCE COMPANY  Avalon Insurance Company
# 4                AVALON INSURANCE COMPANY  Avalon Insurance Company
# ..                                    ...                       ...
# 95  WELLCARE PRESCRIPTION INSURANCE, INC.                  WellCare
# 96  WELLCARE PRESCRIPTION INSURANCE, INC.                  WellCare
# 97  WELLCARE PRESCRIPTION INSURANCE, INC.                  WellCare
# 98  WELLCARE PRESCRIPTION INSURANCE, INC.                  WellCare
# 99  WELLCARE PRESCRIPTION INSURANCE, INC.                  WellCare
#
#                            PlanName  \
# 0               Sterling Retiree Rx
# 1               Sterling Retiree Rx
# 2        AHC Prescription Drug Plan
# 3   SecureRx - ER - Non-Calendar PY
# 4                     SecureRx - ER
# ..                              ...
# 95               WellCare Signature
# 96               WellCare Signature
# 97               WellCare Signature
# 98               WellCare Signature
# 99               WellCare Signature
#
#                             ParentOrganization ContractEffectiveDate  \
# 0                     Sterling Insurance Group    01/01/2006 0:00:00
# 1                     Sterling Insurance Group    01/01/2006 0:00:00
# 2   America's Health Choice Medical Plans, Inc    01/01/2006 0:00:00
# 3                            Capital BlueCross    01/01/2006 0:00:00
# 4                            Capital BlueCross    01/01/2006 0:00:00
# ..                                         ...                   ...
# 95                 WellCare Health Plans, Inc.    01/01/2006 0:00:00
# 96                 WellCare Health Plans, Inc.    01/01/2006 0:00:00
# 97                 WellCare Health Plans, Inc.    01/01/2006 0:00:00
# 98                 WellCare Health Plans, Inc.    01/01/2006 0:00:00
# 99                 WellCare Health Plans, Inc.    01/01/2006 0:00:00
#
#                         Period
# 0   2006-08-01 00:00:00.000000
# 1   2006-08-01 00:00:00.000000
# 2   2006-08-01 00:00:00.000000
# 3   2006-08-01 00:00:00.000000
# 4   2006-08-01 00:00:00.000000
# ..                         ...
# 95  2006-08-01 00:00:00.000000
# 96  2006-08-01 00:00:00.000000
# 97  2006-08-01 00:00:00.000000
# 98  2006-08-01 00:00:00.000000
# 99  2006-08-01 00:00:00.000000
#
# [100 rows x 14 columns]

# %%
db.metadata.tables['meta_downloads']

# %% [markdown]
# # Compare which info in cpsc_contract_info changes

# %%
aug = db.query('SELECT * FROM cpsc_contract_info WHERE Period = "2006-08-01 00:00:00.000000"')
aug.head()
# Out:
#    ID ContractID  PlanID  OrganizationType          PlanType  OffersPartD  \
# 0   1      90091     NaN  HCPP - 1833 Cost  HCPP - 1833 Cost            0
# 1   2      90400     NaN             Pilot             Pilot            0
# 2   3      90401     NaN             Pilot             Pilot            0
# 3   4      90402     NaN             Pilot             Pilot            0
# 4   5      90403     NaN             Pilot             Pilot            0
#
#    SNPPlan  EGHP                             OrganizationName  \
# 0        0     0               UNITED MINE WORKERS OF AMERICA
# 1        0     0                CIGNA MEDICARE HEALTH SUPPORT
# 2        0     0            XL HEALTH MEDICARE HEALTH SUPPORT
# 3        0     0  AMERICAN HEALTHWAYS MEDICARE HEALTH SUPPORT
# 4        0     0             MCKESSON MEDICARE HEALTH SUPPORT
#
#         OrganizationMarketingName PlanName         ParentOrganization  \
# 0  United Mine Workers of America     None                       None
# 1                Cigna Healthcare     None                      CIGNA
# 2           Xl Health Corporation     None                       None
# 3                      Healthways     None  American Healthways, Inc.
# 4       Mckesson Health Solutions     None  McKesson Health Solutions
#
#   ContractEffectiveDate                      Period
# 0    02/01/1974 0:00:00  2006-08-01 00:00:00.000000
# 1    09/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 2    11/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 3    08/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 4    08/01/2005 0:00:00  2006-08-01 00:00:00.000000

# %%
all_months = db.query('SELECT * FROM cpsc_contract_info WHERE Period > "2006-08-00 00:00:00.000000"')
all_months.head()
# Out:
#    ID ContractID  PlanID  OrganizationType          PlanType  OffersPartD  \
# 0   1      90091     NaN  HCPP - 1833 Cost  HCPP - 1833 Cost            0
# 1   2      90400     NaN             Pilot             Pilot            0
# 2   3      90401     NaN             Pilot             Pilot            0
# 3   4      90402     NaN             Pilot             Pilot            0
# 4   5      90403     NaN             Pilot             Pilot            0
#
#    SNPPlan  EGHP                             OrganizationName  \
# 0        0     0               UNITED MINE WORKERS OF AMERICA
# 1        0     0                CIGNA MEDICARE HEALTH SUPPORT
# 2        0     0            XL HEALTH MEDICARE HEALTH SUPPORT
# 3        0     0  AMERICAN HEALTHWAYS MEDICARE HEALTH SUPPORT
# 4        0     0             MCKESSON MEDICARE HEALTH SUPPORT
#
#         OrganizationMarketingName PlanName         ParentOrganization  \
# 0  United Mine Workers of America     None                       None
# 1                Cigna Healthcare     None                      CIGNA
# 2           Xl Health Corporation     None                       None
# 3                      Healthways     None  American Healthways, Inc.
# 4       Mckesson Health Solutions     None  McKesson Health Solutions
#
#   ContractEffectiveDate                      Period
# 0    02/01/1974 0:00:00  2006-08-01 00:00:00.000000
# 1    09/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 2    11/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 3    08/01/2005 0:00:00  2006-08-01 00:00:00.000000
# 4    08/01/2005 0:00:00  2006-08-01 00:00:00.000000

# %%
all_months[all_months.duplicated(subset=['ContractID', 'PlanID'], keep=False)].shape
# Out:
# (10651, 14)

# %%
duplicates = all_months[all_months.duplicated(subset=['ContractID', 'PlanID'], keep=False)]
duplicates.sort_values(by=['ContractID', 'PlanID']).iloc[:3]
# Out:
#         ID ContractID  PlanID  OrganizationType          PlanType  \
# 0        1      90091     NaN  HCPP - 1833 Cost  HCPP - 1833 Cost
# 4923  4924      90091     NaN  HCPP - 1833 Cost  HCPP - 1833 Cost
# 9846  9847      90091     NaN  HCPP - 1833 Cost  HCPP - 1833 Cost
#
#       OffersPartD  SNPPlan  EGHP  \
# 0               0        0     0
# 4923            0        0     0
# 9846            0        0     0
#
#                                       OrganizationName  \
# 0                       UNITED MINE WORKERS OF AMERICA
# 4923                    UNITED MINE WORKERS OF AMERICA
# 9846  UNITED MINE WORKERS OF AMERICA HLTH & RETIREMENT
#
#                               OrganizationMarketingName PlanName  \
# 0                        United Mine Workers of America     None
# 4923                     United Mine Workers of America     None
# 9846  United Mine Workers of America Health & Retire...     None
#
#                     ParentOrganization ContractEffectiveDate  \
# 0                                 None    02/01/1974 0:00:00
# 4923                              None    02/01/1974 0:00:00
# 9846  UMWA Health and Retirement Funds            02/01/1974
#
#                           Period
# 0     2006-08-01 00:00:00.000000
# 4923  2006-09-01 00:00:00.000000
# 9846  2021-06-01 00:00:00.000000

# %%
duplicates.columns
# Out:
# Index(['ID', 'ContractID', 'PlanID', 'OrganizationType', 'PlanType',
#        'OffersPartD', 'SNPPlan', 'EGHP', 'OrganizationName',
#        'OrganizationMarketingName', 'PlanName', 'ParentOrganization',
#        'ContractEffectiveDate', 'Period'],
#       dtype='object')

# %%
duplicates[duplicates.duplicated(subset=['OffersPartD', 'SNPPlan', 'EGHP'], keep=False)].sort_values(by=['ContractID', 'PlanID']).shape
# Out:
# (10651, 14)

# %% [markdown]
# # Schema

# %%
from eralchemy import render_er
## Draw from SQLAlchemy base
#render_er(db.engine, 'erd_from_sqlalchemy.png')

# %%
## Draw from database
render_er("sqlite:///test_db", 'erd_from_sqlite.png')

# %% [markdown]
# # TODO
#
# * x ensure name in download table can be matched to name in data table
# * Do cpsc_contract_info monthly_report_by_contract need to be updated rather than added to?
#     Looks like yes, some information changes, but some plans may also be removed.
# * Switch to MySQL locally to easily handle updates
# * Handle txt files in this batch of files.
# * Consider deploying a Docker container on ECS

# %%
import sqlite3

# %%
con = sqlite3.connect('test_db')

# %%
cursor = con.cursor()

# %%
cursor.execute('SELECT * FROM cpsc_contract_info WHERE Period = "2006-08-01 00:00:00.000000"  LIMIT 10')

# %%
cursor.fetchall()
# Out:
# [(1,
#   '90091',
#   None,
#   'HCPP - 1833 Cost',
#   'HCPP - 1833 Cost',
#   0,
#   0,
#   0,
#   'UNITED MINE WORKERS OF AMERICA',
#   'United Mine Workers of America',
#   None,
#   None,
#   '02/01/1974 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (2,
#   '90400',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'CIGNA MEDICARE HEALTH SUPPORT',
#   'Cigna Healthcare',
#   None,
#   'CIGNA',
#   '09/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (3,
#   '90401',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'XL HEALTH MEDICARE HEALTH SUPPORT',
#   'Xl Health Corporation',
#   None,
#   None,
#   '11/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (4,
#   '90402',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'AMERICAN HEALTHWAYS MEDICARE HEALTH SUPPORT',
#   'Healthways',
#   None,
#   'American Healthways, Inc.',
#   '08/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (5,
#   '90403',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'MCKESSON MEDICARE HEALTH SUPPORT',
#   'Mckesson Health Solutions',
#   None,
#   'McKesson Health Solutions',
#   '08/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (6,
#   '90405',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'GREEN RIBBON HEALTH MEDICARE HEALTH SUPPORT',
#   'Humana Inc.',
#   None,
#   'Humana Inc.',
#   '11/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (7,
#   '90406',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'HEALTH DIAGLOG MEDICARE HEALTH SUPPORT',
#   'Health Diaglog',
#   None,
#   'Health Diaglog',
#   '08/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (8,
#   '90407',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'LIFEMASTERS MEDICARE HEALTH SUPPORT',
#   'Lifemasters Supported Selfcare, Inc.',
#   None,
#   'LifeMasters Supported SelfCare, Inc',
#   '08/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (9,
#   '90408',
#   None,
#   'Pilot',
#   'Pilot',
#   0,
#   0,
#   0,
#   'AETNA MEDICARE HEALTH SUPPORT',
#   'Aetna',
#   None,
#   'Aetna Inc.',
#   '09/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000'),
#  (10,
#   'H0104',
#   1,
#   'Local CCP',
#   'Local PPO',
#   0,
#   0,
#   0,
#   'BLUE CROSS AND BLUE SHIELD OF ALABAMA',
#   'Blue Cross Blue Shield of Alabama',
#   'Blue Advantage Option I',
#   'BlueCross BlueShield of Alabama',
#   '07/01/2005 0:00:00',
#   '2006-08-01 00:00:00.000000')]
